# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
gradebook_raw = pd.read_csv('2025-04-28T0418_Grades-MAC2313-25Spring_0019.csv')
gradebook = gradebook_raw.fillna(0)

# Return the column name with 'keyward'.
def findtestname(keyward, column):
    for str in column:
        if keyward in str:
            return str
    else:
        print(f"Cannot find {keyward} in {column}")
        return None

# %%
webassigngrade = findtestname('WebAssignHomework Final Score', gradebook.columns)
quizgrade = findtestname('WeeklyQuizzes Final Score', gradebook.columns)
test1grade = findtestname('Test1', gradebook.columns)
test2grade = findtestname('Test2', gradebook.columns)
test3grade = findtestname('Test3', gradebook.columns)
finalgrade = findtestname('Final Exam', gradebook.columns)

testdf = gradebook[[test1grade, test2grade, test3grade]]

# %%
gradebook.head()
# Out:
#                           Student         ID  SIS User ID SIS Login ID  \
# 0                 Points Possible        0.0          0.0            0
# 1  Acevedo Castro, Ariel Abimelec  4373833.0    5505497.0     ar184672
# 2            Aldajuste, Weglandsy  4375818.0    5479064.0     we096090
# 3               Arismendi, Julian  4473410.0    5641571.0     ju958713
# 4                   Awai, Kaitlyn  4461982.0    5675074.0     ka905528
#
#          Root Account                Section  \
# 0                   0                      0
# 1  webcourses.ucf.edu  MAC2313-25Spring 0019
# 2  webcourses.ucf.edu  MAC2313-25Spring 0019
# 3  webcourses.ucf.edu  MAC2313-25Spring 0019
# 4  webcourses.ucf.edu  MAC2313-25Spring 0019
#
#    Checkpoint: 2D Vectors (8884222)  Checkpoint: 3D Vectors (8884223)  \
# 0                              10.0                              15.0
# 1                              10.0                              15.0
# 2                               8.0                              13.0
# 3                               7.0                               8.0
# 4                               9.0                              15.0
#
#    Checkpoint: Dot Product (part 1) (8884224)  \
# 0                                        14.0
# 1                                        14.0
# 2                                        13.0
# 3                                        13.0
# 4                                        14.0
#
#    Checkpoint: Dot Product (part 2) (8884225)  ...  Final Final Score  \
# 0                                        12.0  ...        (read only)
# 1                                        12.0  ...              74.00
# 2                                        11.0  ...               0.00
# 3                                         8.0  ...              66.00
# 4                                        12.0  ...              52.00
#
#    Final Unposted Final Score  NongradedAssignments Current Score  \
# 0                 (read only)                         (read only)
# 1                       74.00                               78.84
# 2                        0.00                               33.23
# 3                       66.00                               72.09
# 4                       52.00                               67.38
#
#    NongradedAssignments Unposted Current Score  \
# 0                                  (read only)
# 1                                        78.84
# 2                                        33.23
# 3                                        72.09
# 4                                        67.38
#
#    NongradedAssignments Final Score  \
# 0                       (read only)
# 1                             78.84
# 2                             32.90
# 3                             71.38
# 4                             67.38
#
#    NongradedAssignments Unposted Final Score  Current Score  \
# 0                                (read only)    (read only)
# 1                                      78.84          77.66
# 2                                      32.90          31.07
# 3                                      71.38          71.20
# 4                                      67.38          65.44
#
#    Unposted Current Score  Final Score  Unposted Final Score
# 0             (read only)  (read only)           (read only)
# 1                   77.66        77.66                 77.66
# 2                   31.07        31.07                 31.07
# 3                   71.20        71.20                 71.20
# 4                   65.44        65.44                 65.44
#
# [5 rows x 92 columns]

# %%
# Convert necessary columns to numeric
gradebook[webassigngrade] = pd.to_numeric(gradebook[webassigngrade], errors='coerce')
gradebook[quizgrade] = pd.to_numeric(gradebook[quizgrade], errors='coerce')
gradebook[finalgrade] = pd.to_numeric(gradebook[finalgrade], errors='coerce')

# %%
gradebook.head()
# Out:
#                           Student         ID  SIS User ID SIS Login ID  \
# 0                 Points Possible        0.0          0.0            0
# 1  Acevedo Castro, Ariel Abimelec  4373833.0    5505497.0     ar184672
# 2            Aldajuste, Weglandsy  4375818.0    5479064.0     we096090
# 3               Arismendi, Julian  4473410.0    5641571.0     ju958713
# 4                   Awai, Kaitlyn  4461982.0    5675074.0     ka905528
#
#          Root Account                Section  \
# 0                   0                      0
# 1  webcourses.ucf.edu  MAC2313-25Spring 0019
# 2  webcourses.ucf.edu  MAC2313-25Spring 0019
# 3  webcourses.ucf.edu  MAC2313-25Spring 0019
# 4  webcourses.ucf.edu  MAC2313-25Spring 0019
#
#    Checkpoint: 2D Vectors (8884222)  Checkpoint: 3D Vectors (8884223)  \
# 0                              10.0                              15.0
# 1                              10.0                              15.0
# 2                               8.0                              13.0
# 3                               7.0                               8.0
# 4                               9.0                              15.0
#
#    Checkpoint: Dot Product (part 1) (8884224)  \
# 0                                        14.0
# 1                                        14.0
# 2                                        13.0
# 3                                        13.0
# 4                                        14.0
#
#    Checkpoint: Dot Product (part 2) (8884225)  ...  Final Final Score  \
# 0                                        12.0  ...        (read only)
# 1                                        12.0  ...              74.00
# 2                                        11.0  ...               0.00
# 3                                         8.0  ...              66.00
# 4                                        12.0  ...              52.00
#
#    Final Unposted Final Score  NongradedAssignments Current Score  \
# 0                 (read only)                         (read only)
# 1                       74.00                               78.84
# 2                        0.00                               33.23
# 3                       66.00                               72.09
# 4                       52.00                               67.38
#
#    NongradedAssignments Unposted Current Score  \
# 0                                  (read only)
# 1                                        78.84
# 2                                        33.23
# 3                                        72.09
# 4                                        67.38
#
#    NongradedAssignments Final Score  \
# 0                       (read only)
# 1                             78.84
# 2                             32.90
# 3                             71.38
# 4                             67.38
#
#    NongradedAssignments Unposted Final Score  Current Score  \
# 0                                (read only)    (read only)
# 1                                      78.84          77.66
# 2                                      32.90          31.07
# 3                                      71.38          71.20
# 4                                      67.38          65.44
#
#    Unposted Current Score  Final Score  Unposted Final Score
# 0             (read only)  (read only)           (read only)
# 1                   77.66        77.66                 77.66
# 2                   31.07        31.07                 31.07
# 3                   71.20        71.20                 71.20
# 4                   65.44        65.44                 65.44
#
# [5 rows x 92 columns]

# %%
# Calculate the course grade
# WebAssign Homework, Weekly Quizzes and attendance are out of 100 points, test 1 to test 3 and final exam are out of 50 points.
# WebAssign Homework: 15%, Weekly Quizzes: 17%, Lowest test 13%, Mediem test 16%, Highest test 19%, Final Exam: 20%
coursegrade = 'Course Grade'

gradebook[coursegrade] = (
	0.15 * 100/100 * gradebook[webassigngrade] +
	0.17 * 100/100 * gradebook[quizgrade] +
	0.2 * 100/50 * gradebook[finalgrade] +
	0.13 * 100/50 * testdf.apply(lambda row: sorted(row)[0], axis=1) +
	0.16 * 100/50 * testdf.apply(lambda row: sorted(row)[1], axis=1) +
	0.19 * 100/50 * testdf.apply(lambda row: sorted(row)[2], axis=1)
)

gradebook[['Student', coursegrade, webassigngrade, quizgrade, test1grade, test2grade, test3grade, finalgrade]].sort_values(by=coursegrade, ascending=False)
# Out:
#                              Student  Course Grade  \
# 19                    Howell, Connor       89.4796
# 25                  Koppe, Christian       89.0561
# 43                       Weber, Jake       86.6515
# 27                    Lefever, David       86.2342
# 10                      Chou, Wei-Ni       85.6752
# 15                      Hasan, Tarek       84.6318
# 26                   Latchana, Naomi       82.4306
# 28                     Little, Molly       81.9366
# 21                      Huser, Jacob       81.3626
# 35                    Scavino, Lucas       81.2395
# 38                       Smith, Jake       80.9820
# 1     Acevedo Castro, Ariel Abimelec       78.6235
# 14           Gimeno-Alberti, Gabriel       78.1534
# 36                    Semco, Sheamus       76.5870
# 12                    Cowette, Brady       75.4986
# 8                    Cadena, Nicolas       75.2317
# 13                  Gallmon, Kenneth       75.0061
# 34                      Rush, Connor       74.9879
# 24                   Johnson, Gianna       74.7141
# 30                    McNeal, Collin       74.5850
# 16                   Herrera, Carlos       73.7530
# 3                  Arismendi, Julian       72.0948
# 39                      Spiro, Arden       71.8946
# 31                 Oliveira, Gabriel       71.7874
# 6   Bettarello De Oliveira, Fabricio       70.5414
# 42                        Wax, Dylan       70.3282
# 7                      Bonilla, Ryan       70.1974
# 11                     Cochran, Cade       70.0786
# 18                      Hoel, Robert       68.7844
# 5                    Beaubien, David       67.8365
# 17                   Herrmann, Brian       67.7902
# 4                      Awai, Kaitlyn       67.0567
# 23                     Jaouhar, Ayan       66.4288
# 29                  Malecki, Michael       65.1777
# 20                  Hubner, Fernando       64.8860
# 32                    Remsing, Grant       62.3160
# 37                Serrajian, Sabrina       60.5695
# 22               Jaimovich, Bentzion       52.7011
# 41                    Venkat, Raghav       48.8457
# 40                     Torres, Dylan       45.1773
# 33                   Rodriguez, Axel       39.5923
# 2               Aldajuste, Weglandsy       33.2308
# 9                       Cain, Duncan       30.6208
# 44                     Student, Test        0.0000
# 0                    Points Possible           NaN
#
#     WebAssignHomework Final Score  WeeklyQuizzes Final Score  Test1 (8909620)  \
# 19                          99.74                      96.58             39.0
# 25                          99.74                      97.03             36.0
# 43                          99.47                      86.30             44.0
# 27                         100.00                      97.26             42.0
# 10                          99.74                      95.26             38.0
# 15                          99.46                      93.84             44.0
# 26                          70.72                      91.78             48.0
# 28                          87.64                      94.18             44.0
# 21                         100.00                      91.78             37.0
# 35                          95.95                      87.10             29.0
# 38                          84.66                      89.90             44.0
# 1                          100.00                      89.55             42.0
# 14                          99.22                      67.12             41.0
# 36                         100.00                      91.10             29.0
# 12                          70.29                      45.03             39.0
# 8                           97.59                      85.96             21.0
# 13                          97.55                      84.08             38.0
# 34                         100.00                      86.87             43.0
# 24                         100.00                      89.73             39.0
# 30                          90.73                      95.15             17.0
# 16                          97.61                      89.95             34.0
# 3                           83.19                      81.39             25.0
# 39                         100.00                      95.38             38.0
# 31                          89.84                      82.42             30.0
# 6                           99.74                      96.12             30.0
# 42                          89.33                      83.11             36.0
# 7                           92.84                      84.42             23.0
# 11                          84.64                      91.78             34.0
# 18                          49.85                      75.57             41.0
# 5                           80.67                      50.80             30.0
# 17                          99.45                      80.31             31.0
# 4                           98.69                      87.96             37.0
# 23                          93.09                      95.09             29.0
# 29                          95.66                      79.11             31.0
# 20                         100.00                      77.80             30.0
# 32                          97.26                      39.10             32.0
# 37                          98.66                      84.65             31.0
# 22                          68.18                      85.73             29.0
# 41                          98.36                      67.01             35.0
# 40                          76.26                      59.99             23.0
# 33                          80.00                      32.19             28.0
# 2                           58.55                      36.99             36.0
# 9                           82.23                       6.39             19.0
# 44                           0.00                       0.00              0.0
# 0                             NaN                        NaN             50.0
#
#     Test2 (8909636)  Test3 (8909637)  Final Exam (8909638)
# 19             46.0             39.0                  45.0
# 25             41.0             44.0                  46.0
# 43             41.0             37.0                  44.0
# 27             44.0             39.0                  36.0
# 10             44.0             34.0                  42.0
# 15             41.0             32.0                  39.0
# 26             31.0             36.0                  46.0
# 28             43.0             35.0                  33.0
# 21             33.0             43.0                  35.0
# 35             39.0             39.0                  43.0
# 38             43.0             42.0                  29.0
# 1              34.0             26.0                  37.0
# 14             44.0             37.0                  31.0
# 36             37.0             26.0                  40.0
# 12             40.0             42.0                  46.0
# 8              30.0             34.0                  45.0
# 13             38.0             18.0                  37.0
# 34             33.0             32.0                  25.0
# 24             36.0             22.0                  31.0
# 30             19.0             45.0                  43.0
# 16             28.0             37.0                  29.0
# 3              34.0             40.0                  33.0
# 39             27.0             20.0                  31.0
# 31             27.0             36.0                  35.0
# 6              36.0             26.0                  23.0
# 42             32.0             28.0                  29.0
# 7              25.0             43.0                  29.0
# 11             34.0             23.0                  30.0
# 18             44.0             27.0                  29.0
# 5              36.0             27.0                  42.0
# 17             20.0             27.0                  34.0
# 4              10.0             32.0                  26.0
# 23             33.0             28.0                  18.0
# 29             25.0             20.0                  31.0
# 20             15.0             28.0                  31.0
# 32             32.0             34.0                  24.0
# 37             27.0             38.0                   0.0
# 22             36.0             19.0                   0.0
# 41             18.0             14.0                   0.0
# 40             26.0             24.0                   0.0
# 33             16.0              6.0                  12.0
# 2              14.0              0.0                   0.0
# 9              19.0             15.0                   0.0
# 44              0.0              0.0                   0.0
# 0              50.0             50.0                  50.0

# %%
TestName_searching_keywawrd = coursegrade

testname = findtestname(TestName_searching_keywawrd, gradebook.columns)
testgrade = pd.to_numeric(gradebook[testname], errors='coerce')
testgrade.hist(bins=round(100/5), range = (0,100))
plt.title(f'{testname} histogram')
# Out:
# Text(0.5, 1.0, 'Course Grade histogram')
